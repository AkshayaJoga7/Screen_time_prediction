# %% [markdown]
# 1.Data Loading

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv("screen_time_data.csv")

print("Data Loaded Successfully ✅")
# Out:
# Data Loaded Successfully ✅

# %% [markdown]
# 2.Data Understanding

# %%
print("First 5 rows:")
print(df.head())

print("Last 5 rows:")
print(df.tail())

print("Shape of dataset:")
print(df.shape)

print("Dataset Info:")
print(df.info())

print("Statistical Summary:")
print(df.describe())
# Out:
# First 5 rows:
#          Date  Screen Time  Notifications  Times opened        App
# 0  08/26/2022           38             70            49  Instagram
# 1  08/27/2022           39             43            48  Instagram
# 2  08/28/2022           64            231            55  Instagram
# 3  08/29/2022           14             35            23  Instagram
# 4  08/30/2022            3             19             5  Instagram
# Last 5 rows:
#           Date  Screen Time  Notifications  Times opened       App
# 49  09/17/2022          212            212           120  Whatsapp
# 50  09/18/2022          244            303           132  Whatsapp
# 51  09/19/2022           77            169           105  Whatsapp
# 52  09/20/2022           58            190            78  Whatsapp
# 53  09/21/2022           89            262            68  Whatsapp
# Shape of dataset:
# (54, 5)
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           54 non-null     object
#  1   Screen Time    54 non-null     int64
#  2   Notifications  54 non-null     int64
#  3   Times opened   54 non-null     int64
#  4   App            54 non-null     object
# dtypes: int64(3), object(2)
# memory usage: 2.2+ KB
# None
# Statistical Summary:
#        Screen Time  Notifications  Times opened
# count    54.000000      54.000000     54.000000
# mean     65.037037     117.703704     61.481481
# std      58.317272      97.017530     43.836635
# min       1.000000       8.000000      2.000000
# 25%      17.500000      25.750000     23.500000
# 50%      58.500000      99.000000     62.500000
# 75%      90.500000     188.250000     90.000000
# max     244.000000     405.000000    192.000000

# %% [markdown]
# 3.Data Preprocessing

# %% [markdown]
# Removing Null values

# %%
print("Missing values:")
print(df.isnull().sum())

# If null values exist
df.fillna(method='ffill', inplace=True)
# Out:
# Missing values:
# Date             0
# Screen Time      0
# Notifications    0
# Times opened     0
# App              0
# dtype: int64
# C:\Users\Akshaya\AppData\Local\Temp\ipykernel_12540\3160795413.py:5: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)

# %% [markdown]
# Remove Unnamed columns

# %%
# Remove unnamed columns if present
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %% [markdown]
# Data type conversions

# %%
df['Screen_Minutes'] = df['Screen Time']

# %% [markdown]
# Convert Date to Datetime

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %% [markdown]
# Check Datatypes

# %%
print(df.dtypes)
# Out:
# Date              datetime64[ns]
# Screen Time                int64
# Notifications              int64
# Times opened               int64
# App                       object
# Screen_Minutes             int64
# dtype: object

# %% [markdown]
# Encoding App

# %%
df = pd.get_dummies(df, columns=['App'], drop_first=True)

# %% [markdown]
# 4.Feature Engineering

# %%
df['Day'] = df['Date'].dt.day
df['Month'] = df['Date'].dt.month

# %% [markdown]
# 5.Feature Selection

# %% [markdown]
# Independent Variable (X)

# %%
X = df[['Notifications', 'Times opened', 'App_Whatsapp']]

# %% [markdown]
# Dependent Variable (y)

# %%
y = df['Screen_Minutes']

# %% [markdown]
# 6.Feature Selection

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# 7.Splitting Data

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# %% [markdown]
# 8.Model Selection

# %% [markdown]
# Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error

lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred_lr = lr.predict(X_test)

print("Linear Regression R2:", r2_score(y_test, y_pred_lr))
# Out:
# Linear Regression R2: 0.6938659608875213

# %% [markdown]
# Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

dtr = DecisionTreeRegressor()
dtr.fit(X_train, y_train)

y_pred_dtr = dtr.predict(X_test)

print("Decision Tree R2:", r2_score(y_test, y_pred_dtr))
# Out:
# Decision Tree R2: 0.25519757837431933

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)

y_pred_rf = rf.predict(X_test)

print("Random Forest R2:", r2_score(y_test, y_pred_rf))
# Out:
# Random Forest R2: 0.51526758944215

# %% [markdown]
# Support Vector Regression

# %%
from sklearn.svm import SVR

svr = SVR()
svr.fit(X_train, y_train)

y_pred_svr = svr.predict(X_test)

print("SVR R2:", r2_score(y_test, y_pred_svr))
# Out:
# SVR R2: -0.025870433220516187

# %% [markdown]
# 9.Model Prediction

# %%
# Example: Notifications=200, Times opened=80, Whatsapp=1
new_data = [[200, 80, 1]]

new_data_scaled = scaler.transform(new_data)

prediction = rf.predict(new_data_scaled)

print("Predicted Screen Time (minutes):", prediction[0])
# Out:
# Predicted Screen Time (minutes): 97.59
# c:\Users\Akshaya\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# 10.Save Model

# %%
import pickle

pickle.dump(rf, open("screen_time_model.pkl", "wb"))
pickle.dump(scaler, open("screen_time_scaler.pkl", "wb"))

print("Model Saved Successfully")
# Out:
# Model Saved Successfully

# %% [markdown]
# Model Comparision

# %%
results = {
    "Linear Regression": r2_score(y_test, y_pred_lr),
    "Decision Tree": r2_score(y_test, y_pred_dtr),
    "Random Forest": r2_score(y_test, y_pred_rf),
    "SVR": r2_score(y_test, y_pred_svr)
}

print(results)
# Out:
# {'Linear Regression': 0.6938659608875213, 'Decision Tree': 0.25519757837431933, 'Random Forest': 0.51526758944215, 'SVR': -0.025870433220516187}
